# %%
from spatialfunctions import *

# %%
run_spatial_reasoning()
# Out:
# <span style = 'font-size:20px;'>Test completed! You took 4.20 seconds to complete the test. </br>Correct: 5</br>Wrong: 0</br>You obtained a 100.0%</span>
# <span style = 'font-size:15px;'>Data has been uploaded. Displaying feedback. </span>
# The average score is 3.3
# You are ranked 1 of 20
